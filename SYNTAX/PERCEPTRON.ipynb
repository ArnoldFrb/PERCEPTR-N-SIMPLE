# %% [markdown]
# # PERCEPTRON SIMPLE
# El perceptrón es la forma más simple de una red neuronal usada para la clasificación de un tipo especial de patrones, los linealmente separables (es decir, patrones que se encuentran a ambos lados de un hiperplano). Básicamente, consiste de una neurona con pesos sinápticos y umbral ajustables.

# %% [markdown]
# # ENTRENAMIENTO DE LA RED
# ## CONFIGURACION DE LA RED NEURONAL

# %%
### NUMERO DE ITERACIONES QUE DESEA QUE HAGA LA RED ?
NUMERO_DE_ITERACIONES = 5
### RATA DE APRENDIZAAJE DE LA RED ?
RATA_DE_APRENDIZAJE = 1
### ERROR MAXIMO PERMITIDO DE LA RED
ERROR_MAXIMO_PERMITIDO = 0.1

# %% [markdown]
# ### FUNCION DE SALIDA DE LA RED ?
# - 1 -> FUNCION ESCALON
# - 2 -> FUNCION LINEAL
# - 3 -> FUNCION SIGMOIDE

# %%
FUNCION = 1

# %% [markdown]
# ## CONFIGURACION PARA EL PROGRAMA
# - NOMBRES DE LOS ARCHIVOS DE ENTRADAS Y SALIDAS DE LA RED ?
# - NOMBRE DEL ENTRENAMIENTO ? NOTA: Es utilizado para guardar los pesos y umbrales optimos que encuentra el entrenamiento

# %%
ARCHIVO_ENTRADAS = 'ENTRADAS.TXT'
ARCHIVO_SALIDAS = 'SALIDAS.TXT'
ENTRENAMIENTO = 'COMPUERTA_AND'

# %% [markdown]
# ## CLASE DE INICIALIZACION DE LA RED

# %%
from ConfigEntrenamiento import *

cfe = ConfigEntrenamiento(ARCHIVO_ENTRADAS, ARCHIVO_SALIDAS, ENTRENAMIENTO)
cfe.ENTRENAR_NEURONA(RATA_DE_APRENDIZAJE, ERROR_MAXIMO_PERMITIDO, NUMERO_DE_ITERACIONES, FUNCION)

print(cfe.ENTRENAR_NEURONA)
# Out:
# ---------------------------
# ---------------------------
#
# ---CONFIGURACION---
#
# ---------------------------
# ---------------------------
#
# ---ENTRENAMIENTO---
# ERROR RMS:  0.75
#
# NUMERO DE ITERACIONES REALIZADAS:  5
#
# <bound method ConfigEntrenamiento.ENTRENAR_NEURONA of <ConfigEntrenamiento.ConfigEntrenamiento object at 0x00000199D52C4C70>>

# %%
# SIMULACION DE LA RED
### NOMBRE DEL ENTRENAMIENTO QUE DESEA SIMULAR ?
# Out:
# ---------------------------
# ---------------------------
#
# ---CONFIGURACION---
#
# ENTRADAS:  2
# SALIDAS:  1
# PATRONES:  4
#
# PESOS:
# [[0.26 0.94]]
#
# UMBRALES:
# [0.97]
# ---------------------------
# ---------------------------
#
# ---SIMULACION---
#
# PATRON:  1
#
# Xi => YDi
# [0. 0.]  =>  [0]
# -------------------
#
# PATRON:  2
#
# Xi => YDi
# [0. 1.]  =>  [0]
# -------------------
#
# PATRON:  3
#
# Xi => YDi
# [1. 0.]  =>  [0]
# -------------------
#
# PATRON:  4
#
# Xi => YDi
# [1. 1.]  =>  [1]
# -------------------

# %%
ENTRENAMIENTO = 'COMPUERTA_AND'

# %% [markdown]
# ### FUNCION DE SALIDA DE LA RED ?
# - 1 -> FUNCION ESCALON
# - 2 -> FUNCION LINEAL
# - 3 -> FUNCION SIGMOIDE

# %%
FUNCION = 1

# %%
from ConfigSimulacion import *

cfs = ConfigSimulacion(ARCHIVO_ENTRADAS, ENTRENAMIENTO, FUNCION)
cfs.SIMULACION()
